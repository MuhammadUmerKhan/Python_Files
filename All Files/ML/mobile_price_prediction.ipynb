# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('mobile phone price prediction.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                                  Name  Rating  Spec_score  \
# 0           0                 Samsung Galaxy F14 5G    4.65          68
# 1           1                    Samsung Galaxy A11    4.20          63
# 2           2                    Samsung Galaxy A13    4.30          75
# 3           3                    Samsung Galaxy F23    4.10          73
# 4           4  Samsung Galaxy A03s (4GB RAM + 64GB)    4.10          69
#
#                        No_of_sim       Ram            Battery     Display  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE,   4 GB RAM  6000 mAh Battery   6.6 inches
# 1      Dual Sim, 3G, 4G, VoLTE,   2 GB RAM  4000 mAh Battery   6.4 inches
# 2      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM  5000 mAh Battery   6.6 inches
# 3      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM   6000 mAh Battery  6.4 inches
# 4      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM  5000 mAh Battery   6.5 inches
#
#                                               Camera  \
# ...

# %%
data.drop(columns='Unnamed: 0', inplace=True)

# %%
data.sample(3)
# Out:
#                                    Name  Rating  Spec_score  \
# 1326                 Lava Yuva 4 Pro 5G    4.35          77
# 608   Honor Magic V2 RSR Porsche Design    4.75          93
# 1180        Xiaomi Redmi Note 12 Pro 4G    4.65          73
#
#                           No_of_sim        Ram            Battery  \
# 1326  Dual Sim, 3G, 4G, 5G, VoLTE,    8 GB RAM  5000 mAh Battery
# 608   Dual Sim, 3G, 4G, 5G, VoLTE,   16 GB RAM  5000 mAh Battery
# 1180      Dual Sim, 3G, 4G, VoLTE,    6 GB RAM  5000 mAh Battery
#
#           Display                                           Camera  \
# 1326  6.58 inches  50 MP + 2 MP Dual Rear &amp; 16 MP Front Camera
# 608   7.92 inches                   Foldable Display, Dual Display
# 1180  6.67 inches        108 MP Quad Rear &amp; 16 MP Front Camera
#
#                                         External_Memory Android_version  \
# 1326                   Memory Card Supported, upto 1 TB              14
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Rating', 'Spec_score', 'No_of_sim', 'Ram', 'Battery',
#        'Display', 'Camera', 'External_Memory', 'Android_version', 'Price',
#        'company', 'Inbuilt_memory', 'fast_charging', 'Screen_resolution',
#        'Processor', 'Processor_name'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               1370 non-null   object
#  1   Rating             1370 non-null   float64
#  2   Spec_score         1370 non-null   int64
#  3   No_of_sim          1370 non-null   object
#  4   Ram                1370 non-null   object
#  5   Battery            1370 non-null   object
#  6   Display            1370 non-null   object
#  7   Camera             1370 non-null   object
#  8   External_Memory    1370 non-null   object
#  9   Android_version    927 non-null    object
#  10  Price              1370 non-null   object
#  11  company            1370 non-null   object
#  12  Inbuilt_memory     1351 non-null   object
#  13  fast_charging      1281 non-null   object
#  14  Screen_resolution  1368 non-null   object
#  15  Processor          1342 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# Name                   0
# Rating                 0
# Spec_score             0
# No_of_sim              0
# Ram                    0
# Battery                0
# Display                0
# Camera                 0
# External_Memory        0
# Android_version      443
# Price                  0
# company                0
# Inbuilt_memory        19
# fast_charging         89
# Screen_resolution      2
# Processor             28
# Processor_name         0
# dtype: int64

# %%
data.shape
# Out:
# (1370, 17)

# %%
(443/1370)*100
# Out:
# 32.33576642335766

# %%
data['Name'].value_counts()
# Out:
# Name
# Realme Narzo N55 (6GB RAM + 128GB)    3
# Vivo V30 Pro (12GB RAM + 512GB)       2
# Vivo S19 Pro                          2
# Vivo V25 Pro (12GB RAM + 256GB)       2
# Vivo V30 5G                           2
#                                      ..
# POCO C31 (4GB RAM + 64GB)             1
# Poco C65 (6GB RAM + 128GB)            1
# Poco C50 (3GB RAM + 32GB)             1
# Poco C55                              1
# TCL Trifold                           1
# Name: count, Length: 1334, dtype: int64

# %%
data.drop(columns= 'Name', inplace=True)

# %%
data['Price'] = data['Price'].str.replace(',', '').astype(int)

# %%
data.head(2)
# Out:
#    Rating  Spec_score                      No_of_sim       Ram  \
# 0    4.65          68  Dual Sim, 3G, 4G, 5G, VoLTE,   4 GB RAM
# 1    4.20          63      Dual Sim, 3G, 4G, VoLTE,   2 GB RAM
#
#              Battery     Display  \
# 0  6000 mAh Battery   6.6 inches
# 1  4000 mAh Battery   6.4 inches
#
#                                               Camera  \
# 0    50 MP + 2 MP Dual Rear &amp; 13 MP Front Camera
# 1  13 MP + 5 MP + 2 MP Triple Rear &amp; 8 MP Fro...
#
#                       External_Memory Android_version  Price  company  \
# 0    Memory Card Supported, upto 1 TB              13   9999  Samsung
# 1  Memory Card Supported, upto 512 GB              10   9990  Samsung
#
#     Inbuilt_memory       fast_charging  \
# 0   128 GB inbuilt   25W Fast Charging
# 1    32 GB inbuilt   15W Fast Charging
#
#                                Screen_resolution             Processor  \
# 0   2408 x 1080 px Display with Water Drop Notch   Octa Core Processor
# ...

# %%
data['Ram'] = data['Ram'].astype(str).str.extract('(\d+)').astype(int)
data['Battery'] = data['Battery'].astype(str).str.extract('(\d+)').astype(int)
data['Display'] = data['Display'].astype(str).str.extract('(\d+)').astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\muham\AppData\Local\Temp\ipykernel_12572\3928749143.py:1: SyntaxWarning: invalid escape sequence '\d'
#   data['Ram'] = data['Ram'].astype(str).str.extract('(\d+)').astype(int)
# C:\Users\muham\AppData\Local\Temp\ipykernel_12572\3928749143.py:2: SyntaxWarning: invalid escape sequence '\d'
#   data['Battery'] = data['Battery'].astype(str).str.extract('(\d+)').astype(int)
# C:\Users\muham\AppData\Local\Temp\ipykernel_12572\3928749143.py:3: SyntaxWarning: invalid escape sequence '\d'
#   data['Display'] = data['Display'].astype(str).str.extract('(\d+)').astype(float)

# %%
data.isna().sum()
# Out:
# Rating                 0
# Spec_score             0
# No_of_sim              0
# Ram                    0
# Battery                0
# Display                0
# Camera                 0
# External_Memory        0
# Android_version      443
# Price                  0
# company                0
# Inbuilt_memory        19
# fast_charging         89
# Screen_resolution      2
# Processor             28
# Processor_name         0
# dtype: int64

# %%
data['Inbuilt_memory'].fillna(data['Inbuilt_memory'].mode()[0], inplace=True)
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_12572\1205435569.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Inbuilt_memory'].fillna(data['Inbuilt_memory'].mode()[0], inplace=True)

# %%
data['Inbuilt_memory'] = data['Inbuilt_memory'].astype(str).str.extract('(\d+)')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\muham\AppData\Local\Temp\ipykernel_12572\1289002770.py:1: SyntaxWarning: invalid escape sequence '\d'
#   data['Inbuilt_memory'] = data['Inbuilt_memory'].astype(str).str.extract('(\d+)')

# %%
data['Inbuilt_memory'].dropna(inplace=True)

# %%
data[data.duplicated()]
# Out:
#       Rating  Spec_score                      No_of_sim  Ram  Battery  \
# 1126    4.15          90  Dual Sim, 3G, 4G, 5G, VoLTE,    16     5000
#
#       Display                                             Camera  \
# 1126      6.0  50 MP + 48 MP + 32 MP Triple Rear &amp; 16 MP ...
#
#                 External_Memory Android_version  Price  company  \
# 1126  Memory Card Not Supported              13  64990  OnePlus
#
#      Inbuilt_memory        fast_charging Screen_resolution   Processor  \
# 1126            256   100W Fast Charging    1440 x 3216 px   Octa Core
#
#          Processor_name
# 1126  Snapdragon 8 Gen2

# %%
data.drop_duplicates(inplace=True)

# %%
data.head(2)
# Out:
#    Rating  Spec_score                      No_of_sim  Ram  Battery  Display  \
# 0    4.65          68  Dual Sim, 3G, 4G, 5G, VoLTE,     4     6000      6.0
# 1    4.20          63      Dual Sim, 3G, 4G, VoLTE,     2     4000      6.0
#
#                                               Camera  \
# 0    50 MP + 2 MP Dual Rear &amp; 13 MP Front Camera
# 1  13 MP + 5 MP + 2 MP Triple Rear &amp; 8 MP Fro...
#
#                       External_Memory Android_version  Price  company  \
# 0    Memory Card Supported, upto 1 TB              13   9999  Samsung
# 1  Memory Card Supported, upto 512 GB              10   9990  Samsung
#
#   Inbuilt_memory       fast_charging  \
# 0            128   25W Fast Charging
# 1             32   15W Fast Charging
#
#                                Screen_resolution             Processor  \
# 0   2408 x 1080 px Display with Water Drop Notch   Octa Core Processor
# 1          720 x 1560 px Display with Punch Hole     1.8 GHz Processor
#
#   Processor_name
# ...

# %%
data['fast_charging'].value_counts()
# Out:
# fast_charging
# 18W Fast Charging      157
# 33W Fast Charging      144
# 67W Fast Charging      101
# 25W Fast Charging       97
# 80W Fast Charging       78
# 100W Fast Charging      69
# 66W Fast Charging       66
# 120W Fast Charging      65
# 15W Fast Charging       61
# 44W Fast Charging       61
# 45W Fast Charging       58
# 65W Fast Charging       50
# 30W Fast Charging       44
# 10W Fast Charging       39
# Fast Charging           39
# 150W Fast Charging      24
# 22.5W Fast Charging     20
# 68W Fast Charging       20
# 40W Fast Charging       17
# 35W Fast Charging       14
# 125W Fast Charging      12
# 20W Fast Charging       11
# 200W Fast Charging       7
# 240W Fast Charging       3
# 55W Fast Charging        3
# 90W Fast Charging        3
# 88W Fast Charging        3
# 50W Fast Charging        2
# 250W Fast Charging       2
# 27W Fast Charging        2
# 57W Fast Charging        1
# 60W Fast Charging        1
# 08W Fast Charging        1
# ...

# %%
data['fast_charging'] = data['fast_charging'].astype(str).str.extract('(\d+)').astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\muham\AppData\Local\Temp\ipykernel_12572\2762642277.py:1: SyntaxWarning: invalid escape sequence '\d'
#   data['fast_charging'] = data['fast_charging'].astype(str).str.extract('(\d+)').astype(float)

# %%
data.head(1)
# Out:
#    Rating  Spec_score                      No_of_sim  Ram  Battery  Display  \
# 0    4.65          68  Dual Sim, 3G, 4G, 5G, VoLTE,     4     6000      6.0
#
#                                             Camera  \
# 0  50 MP + 2 MP Dual Rear &amp; 13 MP Front Camera
#
#                     External_Memory Android_version  Price  company  \
# 0  Memory Card Supported, upto 1 TB              13   9999  Samsung
#
#   Inbuilt_memory  fast_charging  \
# 0            128           25.0
#
#                                Screen_resolution             Processor  \
# 0   2408 x 1080 px Display with Water Drop Notch   Octa Core Processor
#
#   Processor_name
# 0    Exynos 1330

# %%
data.drop(columns=['Processor_name'], inplace=True)

# %%
data.head()
# Out:
#    Rating  Spec_score                      No_of_sim  Ram  Battery  Display  \
# 0    4.65          68  Dual Sim, 3G, 4G, 5G, VoLTE,     4     6000      6.0
# 1    4.20          63      Dual Sim, 3G, 4G, VoLTE,     2     4000      6.0
# 2    4.30          75      Dual Sim, 3G, 4G, VoLTE,     4     5000      6.0
# 3    4.10          73      Dual Sim, 3G, 4G, VoLTE,     4     6000      6.0
# 4    4.10          69      Dual Sim, 3G, 4G, VoLTE,     4     5000      6.0
#
#                                               Camera  \
# 0    50 MP + 2 MP Dual Rear &amp; 13 MP Front Camera
# 1  13 MP + 5 MP + 2 MP Triple Rear &amp; 8 MP Fro...
# 2            50 MP Quad Rear &amp; 8 MP Front Camera
# 3           48 MP Quad Rear &amp; 13 MP Front Camera
# 4  13 MP + 2 MP + 2 MP Triple Rear &amp; 5 MP Fro...
#
#                       External_Memory Android_version  Price  company  \
# 0    Memory Card Supported, upto 1 TB              13   9999  Samsung
# ...

# %%
data.isna().sum()
# Out:
# Rating                 0
# Spec_score             0
# No_of_sim              0
# Ram                    0
# Battery                0
# Display                0
# Camera                 0
# External_Memory        0
# Android_version      443
# Price                  0
# company                0
# Inbuilt_memory         1
# fast_charging        129
# Screen_resolution      2
# Processor             28
# dtype: int64
